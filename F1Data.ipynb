# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from dfply import *
from more_dfply import ifelse, case_when
from more_dfply.facets import text_facet, text_filter

# %%
circuits = pd.read_csv('./data/circuits.csv', na_values=r'\N')
constructor_results = pd.read_csv('./data/constructor_results.csv')
constructor_standings = pd.read_csv('./data/constructor_standings.csv')
constructors = pd.read_csv('data/constructors.csv')
driver_standings = pd.read_csv('data/driver_standings.csv')
drivers = pd.read_csv('data/drivers.csv', na_values=r'\N')
lap_times = pd.read_csv('data/lap_times.csv', na_values=r'\N')
pit_stops = pd.read_csv('data/pit_stops.csv', na_values=r'\N')
qualifying = pd.read_csv('data/qualifying.csv', na_values=r'\N')
races = pd.read_csv('data/races.csv', na_values = r'\N')
results = pd.read_csv('data/results.csv', na_values=r'\N')
seasons = pd.read_csv('data/seasons.csv')
sprint_results = pd.read_csv('data/sprint_results.csv')
status = pd.read_csv('data/status.csv')

# %%
constructor_to_standings = (constructors >> left_join(constructor_standings, by='constructorId'))
standings_to_results = (constructor_to_standings >> left_join(constructor_results, by=['constructorId', 'raceId']))
results_to_races = (standings_to_results >> left_join(races, by='raceId'))
results_to_races
# Out:
#        constructorId constructorRef          name_x nationality  \
# 0                  1        mclaren         McLaren     British
# 1                  1        mclaren         McLaren     British
# 2                  1        mclaren         McLaren     British
# 3                  1        mclaren         McLaren     British
# 4                  1        mclaren         McLaren     British
# 5                  1        mclaren         McLaren     British
# 6                  1        mclaren         McLaren     British
# 7                  1        mclaren         McLaren     British
# 8                  1        mclaren         McLaren     British
# ...              ...            ...             ...         ...
# 12884            214         alpine  Alpine F1 Team      French
# 12885            214         alpine  Alpine F1 Team      French
# 12886            214         alpine  Alpine F1 Team      French
# 12887            214         alpine  Alpine F1 Team      French
# 12888            214         alpine  Alpine F1 Team      French
# 12889            214         alpine  Alpine F1 Team      French
# 12890            214         alpine  Alpine F1 Team      French
# 12891            214         alpine  Alpine F1 Team      French
# 12892            214         alpine  Alpine F1 Team      French
#
#                                              url_x  constructorStandingsId  \
# 0             http://en.wikipedia.org/wiki/McLaren                     1.0
# 1             http://en.wikipedia.org/wiki/McLaren                     7.0
# 2             http://en.wikipedia.org/wiki/McLaren                    18.0
# 3             http://en.wikipedia.org/wiki/McLaren                    29.0
# 4             http://en.wikipedia.org/wiki/McLaren                    40.0
# 5             http://en.wikipedia.org/wiki/McLaren                    51.0
# 6             http://en.wikipedia.org/wiki/McLaren                    62.0
# 7             http://en.wikipedia.org/wiki/McLaren                    73.0
# 8             http://en.wikipedia.org/wiki/McLaren                    84.0
# ...                                            ...                     ...
# 12884  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28177.0
# 12885  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28187.0
# 12886  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28197.0
# 12887  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28207.0
# 12888  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28227.0
# 12889  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28237.0
# 12890  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28247.0
# 12891  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28257.0
# 12892  http://en.wikipedia.org/wiki/Alpine_F1_Team                 28267.0
#
#        raceId  points_x  position positionText  ...    fp1_date  fp1_time  \
# 0        18.0      14.0       1.0            1  ...         NaN       NaN
# 1        19.0      24.0       1.0            1  ...         NaN       NaN
# 2        20.0      28.0       3.0            3  ...         NaN       NaN
# 3        21.0      34.0       3.0            3  ...         NaN       NaN
# 4        22.0      42.0       3.0            3  ...         NaN       NaN
# 5        23.0      53.0       2.0            2  ...         NaN       NaN
# 6        24.0      53.0       3.0            3  ...         NaN       NaN
# 7        25.0      58.0       3.0            3  ...         NaN       NaN
# 8        26.0      72.0       3.0            3  ...         NaN       NaN
# ...       ...       ...       ...          ...  ...         ...       ...
# 12884  1078.0      26.0       6.0            6  ...  2022-05-06  18:30:00
# 12885  1079.0      34.0       6.0            6  ...  2022-05-20  12:00:00
# 12886  1080.0      40.0       6.0            6  ...  2022-05-27  12:00:00
# 12887  1081.0      47.0       5.0            5  ...  2022-06-10  11:00:00
# 12888  1082.0      57.0       5.0            5  ...  2022-06-17  18:00:00
# 12889  1083.0      67.0       5.0            5  ...  2022-07-01  12:00:00
# 12890  1084.0      81.0       5.0            5  ...  2022-07-08  11:30:00
# 12891  1085.0      93.0       4.0            4  ...  2022-07-22  12:00:00
# 12892  1086.0      99.0       4.0            4  ...  2022-07-29  12:00:00
#
#          fp2_date  fp2_time    fp3_date  fp3_time  quali_date quali_time  \
# 0             NaN       NaN         NaN       NaN         NaN        NaN
# 1             NaN       NaN         NaN       NaN         NaN        NaN
# 2             NaN       NaN         NaN       NaN         NaN        NaN
# 3             NaN       NaN         NaN       NaN         NaN        NaN
# 4             NaN       NaN         NaN       NaN         NaN        NaN
# 5             NaN       NaN         NaN       NaN         NaN        NaN
# 6             NaN       NaN         NaN       NaN         NaN        NaN
# 7             NaN       NaN         NaN       NaN         NaN        NaN
# 8             NaN       NaN         NaN       NaN         NaN        NaN
# ...           ...       ...         ...       ...         ...        ...
# 12884  2022-05-06  21:30:00  2022-05-07  17:00:00  2022-05-07   20:00:00
# 12885  2022-05-20  15:00:00  2022-05-21  11:00:00  2022-05-21   14:00:00
# 12886  2022-05-27  15:00:00  2022-05-28  11:00:00  2022-05-28   14:00:00
# 12887  2022-06-10  14:00:00  2022-06-11  11:00:00  2022-06-11   14:00:00
# 12888  2022-06-17  21:00:00  2022-06-18  17:00:00  2022-06-18   20:00:00
# 12889  2022-07-01  15:00:00  2022-07-02  11:00:00  2022-07-02   14:00:00
# 12890  2022-07-09  10:30:00         NaN       NaN  2022-07-08   15:00:00
# 12891  2022-07-22  15:00:00  2022-07-23  11:00:00  2022-07-23   14:00:00
# 12892  2022-07-29  15:00:00  2022-07-30  11:00:00  2022-07-30   14:00:00
#
#       sprint_date sprint_time
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# 5             NaN         NaN
# 6             NaN         NaN
# 7             NaN         NaN
# 8             NaN         NaN
# ...           ...         ...
# 12884         NaN         NaN
# 12885         NaN         NaN
# 12886         NaN         NaN
# 12887         NaN         NaN
# 12888         NaN         NaN
# 12889         NaN         NaN
# 12890  2022-07-09    14:30:00
# 12891         NaN         NaN
# 12892         NaN         NaN
#
# [12893 rows x 31 columns]

# %%
results_to_races.columns
# Out:
# Index(['constructorId', 'constructorRef', 'name_x', 'nationality', 'url_x',
#        'constructorStandingsId', 'raceId', 'points_x', 'position',
#        'positionText', 'wins', 'constructorResultsId', 'points_y', 'status',
#        'year', 'round', 'circuitId', 'name_y', 'date', 'time', 'url_y',
#        'fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
#        'quali_date', 'quali_time', 'sprint_date', 'sprint_time'],
#       dtype='object')

# %%
split_and_get = lambda character, position: X.date.str.split(character).str.get(position)
qualified = lambda teamname, year: if_else((X['name'] == teamname) & (X.year == year), "yes", "no")

results_cleaned = (results_to_races
                    >> select(X.constructorId, X.constructorRef, X.name_x, X.nationality, X.constructorStandingsId, X.raceId, X.points_x, X.year, X.circuitId, X.date)
                    >> mutate(name = X.name_x)
                    >> mutate(points = X.points_x)
                    >> drop(X.points_x, X.name_x, X.year) ### dropped year because the dtype was float as well as the date column provides exact date, using that to grab info
                    >> group_by(X.name)
                    >> mutate(year = split_and_get('-', 0))
                    >> mutate(month = split_and_get('-', 1))
                    >> mutate(day = split_and_get('-', 2))
                    >> drop(X.date)
                    # >> mutate(era = ifelse(X.year >= 1950 & X.year <= 1951, 'Front Engine Era', 'other'))
                    >> mutate(disqualified = qualified('McLaren', '2007'))
                    >> filter_by(X.disqualified == 'no')
)
results_cleaned
# Out:
#        constructorId constructorRef nationality  constructorStandingsId  \
# 11375            147            afm      German                     NaN
# 8372              39            ags      French                  8254.0
# 8373              39            ags      French                  8272.0
# 8374              39            ags      French                  8291.0
# 8375              39            ags      French                  8310.0
# 8376              39            ags      French                  8329.0
# 8377              39            ags      French                  8348.0
# 8378              39            ags      French                  8367.0
# 8379              39            ags      French                  8386.0
# ...              ...            ...         ...                     ...
# 8944              49       zakspeed      German                 10079.0
# 8945              49       zakspeed      German                 10095.0
# 8946              49       zakspeed      German                 10111.0
# 8947              49       zakspeed      German                 10127.0
# 8948              49       zakspeed      German                 10143.0
# 8949              49       zakspeed      German                 10160.0
# 8950              49       zakspeed      German                 10177.0
# 8951              49       zakspeed      German                 10194.0
# 8952              49       zakspeed      German                 10211.0
#
#        raceId  circuitId      name  points  year month  day disqualified
# 11375     NaN        NaN       AFM     NaN   NaN   NaN  NaN           no
# 8372    306.0       18.0       AGS     0.0  1991    03   24           no
# 8373    307.0       21.0       AGS     0.0  1991    04   28           no
# 8374    308.0        6.0       AGS     0.0  1991    05   12           no
# 8375    309.0        7.0       AGS     0.0  1991    06   02           no
# 8376    310.0       32.0       AGS     0.0  1991    06   16           no
# 8377    311.0        8.0       AGS     0.0  1991    07   07           no
# 8378    312.0        9.0       AGS     0.0  1991    07   14           no
# 8379    313.0       10.0       AGS     0.0  1991    07   28           no
# ...       ...        ...       ...     ...   ...   ...  ...          ...
# 8944    427.0        9.0  Zakspeed     0.0  1985    07   21           no
# 8945    428.0       20.0  Zakspeed     0.0  1985    08   04           no
# 8946    429.0       70.0  Zakspeed     0.0  1985    08   18           no
# 8947    430.0       39.0  Zakspeed     0.0  1985    08   25           no
# 8948    431.0       14.0  Zakspeed     0.0  1985    09   08           no
# 8949    432.0       13.0  Zakspeed     0.0  1985    09   15           no
# 8950    433.0       38.0  Zakspeed     0.0  1985    10   06           no
# 8951    434.0       30.0  Zakspeed     0.0  1985    10   19           no
# 8952    435.0       29.0  Zakspeed     0.0  1985    11   03           no
#
# [12876 rows x 12 columns]

# %%
results_cleaned.dtypes
# Out:
# constructorId               int64
# constructorRef             object
# nationality                object
# constructorStandingsId    float64
# raceId                    float64
# circuitId                 float64
# name                       object
# points                    float64
# year                       object
# month                      object
# day                        object
# disqualified               object
# dtype: object

# %%
seasons_points = (results_cleaned
                    >> group_by(X.year, X.name, X.constructorId, X.constructorRef, X.nationality)
                    >> summarize(finalpoints = X.points.max())
)
seasons_points
# Out:
#     nationality constructorRef  constructorId            name  year  \
# 0       British            brm             66             BRM  1958
# 1       British      connaught            125       Connaught  1958
# 2       British         cooper             87          Cooper  1958
# 3       Italian        ferrari              6         Ferrari  1958
# 4       Italian       maserati            105        Maserati  1958
# 5       Italian           osca            127            OSCA  1958
# 6        German        porsche             95         Porsche  1958
# 7       British     team_lotus             32      Team Lotus  1958
# 8       British        vanwall            118         Vanwall  1958
# ..          ...            ...            ...             ...   ...
# 890     Italian     alphatauri            213      AlphaTauri  2022
# 891      French         alpine            214  Alpine F1 Team  2022
# 892     British   aston_martin            117    Aston Martin  2022
# 893     Italian        ferrari              6         Ferrari  2022
# 894    American           haas            210    Haas F1 Team  2022
# 895     British        mclaren              1         McLaren  2022
# 896      German       mercedes            131        Mercedes  2022
# 897    Austrian       red_bull              9        Red Bull  2022
# 898     British       williams              3        Williams  2022
#
#      finalpoints
# 0           18.0
# 1            0.0
# 2           31.0
# 3           40.0
# 4            6.0
# 5            0.0
# 6            0.0
# 7            3.0
# 8           48.0
# ..           ...
# 890         27.0
# 891         99.0
# 892         20.0
# 893        334.0
# 894         34.0
# 895         95.0
# 896        304.0
# 897        431.0
# 898          3.0
#
# [899 rows x 6 columns]

# %%
truemax = (seasons_points
            >> group_by(X.year)
            >> summarize(maxpoints = X.finalpoints.max()))
truemax
# Out:
#     year  maxpoints
# 0   1958       48.0
# 1   1959       40.0
# 2   1960       48.0
# 3   1961       45.0
# 4   1962       42.0
# 5   1963       54.0
# 6   1964       45.0
# 7   1965       54.0
# 8   1966       42.0
# ..   ...        ...
# 56  2014      701.0
# 57  2015      703.0
# 58  2016      765.0
# 59  2017      668.0
# 60  2018      655.0
# 61  2019      739.0
# 62  2020      573.0
# 63  2021      613.5
# 64  2022      431.0
#
# [65 rows x 2 columns]

# %%
pd.set_option('display.max_rows', False)

names_recode = {'Team Lotus':'Lotus-Ford', 'Tyrrell':'Tyrrell-Ford', 'Williams':'Williams-Ford', 'Ferrari':'Ferrari', 'Cooper-Climax':'Cooper-Climax',
                'BRM':'BRM', 'Lotus-Climax':'Lotus-Climax', 'Brabham-Repco':'Brabham-Repco', 'Lotus-Ford':'Lotus-Ford', 'Matra-Ford':'Matra-Ford',
                'McLaren':'McLaren', 'Benetton':'Benetton', 'Renault':'Renault', 'Brawn':'Brawn', 'Red Bull':'Red Bull', 'Mercedes':'Mercedes', 'Vanwall':'Vanwall'}


points_max_join = (seasons_points >> inner_join(truemax,by='year'))
constructor_champions = (points_max_join
             >> mutate(team_percents = X.finalpoints/X.maxpoints)
             >> mutate(name = X.name.map(names_recode))
             >> filter_by(X.team_percents==1)
             >> drop(X.team_percents, X.maxpoints)
             >> mutate(constructorId = X.constructorId.astype(str))
)
constructor_champions
# Out:
#     nationality constructorRef constructorId           name  year  finalpoints
# 8       British        vanwall           118        Vanwall  1958         48.0
# 13      British  cooper-climax           170  Cooper-Climax  1959         40.0
# 29      British  cooper-climax           170  Cooper-Climax  1960         48.0
# 44      Italian        ferrari             6        Ferrari  1961         45.0
# 51      British            brm            66            BRM  1962         42.0
# 85      British   lotus-climax           172   Lotus-Climax  1963         54.0
# 99      Italian        ferrari             6        Ferrari  1964         45.0
# 118     British   lotus-climax           172   Lotus-Climax  1965         54.0
# 124     British  brabham-repco           191  Brabham-Repco  1966         42.0
# ..          ...            ...           ...            ...   ...          ...
# 813      German       mercedes           131       Mercedes  2014        701.0
# 823      German       mercedes           131       Mercedes  2015        703.0
# 833      German       mercedes           131       Mercedes  2016        765.0
# 843      German       mercedes           131       Mercedes  2017        668.0
# 853      German       mercedes           131       Mercedes  2018        655.0
# 863      German       mercedes           131       Mercedes  2019        739.0
# 874      German       mercedes           131       Mercedes  2020        573.0
# 886      German       mercedes           131       Mercedes  2021        613.5
# 897    Austrian       red_bull             9       Red Bull  2022        431.0
#
# [65 rows x 6 columns]

# %% [markdown]
# ***years off*** -
# ***2007(mclaren -> ferrari) because mclaren was disqualfied that season***

# %%
countedteams = (constructor_champions
                >> group_by(X.name)
                >> summarize(championships = X.constructorRef.count())
                >> ungroup
                >> arrange(X.championships, ascending = False)
)
countedteams
# Out:
#              name  championships
# 5         Ferrari             16
# 15  Williams-Ford              9
# 9         McLaren              8
# 10       Mercedes              8
# 7      Lotus-Ford              5
# 11       Red Bull              5
# 2   Brabham-Repco              2
# 4   Cooper-Climax              2
# 6    Lotus-Climax              2
# 12        Renault              2
# 0             BRM              1
# 1        Benetton              1
# 3           Brawn              1
# 8      Matra-Ford              1
# 13   Tyrrell-Ford              1
# 14        Vanwall              1

# %%
teamsoverfive = (countedteams
            >> filter_by(X.championships >= 5)
)
teamsoverfive
# Out:
#              name  championships
# 5         Ferrari             16
# 15  Williams-Ford              9
# 9         McLaren              8
# 10       Mercedes              8
# 7      Lotus-Ford              5
# 11       Red Bull              5

# %%
topteams = (points_max_join
            >> mutate(team_percents = X.finalpoints/65)
            >> mutate(name = X.name.map(names_recode))
            >> group_by(X.name)
            >> summarize(overall = X.team_percents.mean())
            >> ungroup
            >> arrange(X.overall, ascending = False)
)
topteams
# Out:
#              name   overall
# 10       Mercedes  7.813609
# 11       Red Bull  5.179487
# 3           Brawn  2.646154
# 5         Ferrari  2.131124
# 9         McLaren  1.715237
# 15  Williams-Ford  1.176105
# 12        Renault  1.139103
# 8      Matra-Ford  0.853846
# 1        Benetton  0.828365
# 6    Lotus-Climax  0.492308
# 7      Lotus-Ford  0.475604
# 2   Brabham-Repco  0.442308
# 4   Cooper-Climax  0.328205
# 13   Tyrrell-Ford  0.327321
# 0             BRM  0.296154
# 14        Vanwall  0.246154

# %%
# Why are the years off?

find_2007 = (seasons_points
            >> group_by (X.name)
            >> filter_by(X.year == '2007')
)
find_2007
# Out:
#     nationality constructorRef  constructorId         name  year  finalpoints
# 729      German     bmw_sauber              2   BMW Sauber  2007        101.0
# 730     Italian        ferrari              6      Ferrari  2007        204.0
# 731    Japanese          honda             11        Honda  2007          6.0
# 732    Austrian       red_bull              9     Red Bull  2007         24.0
# 733      French        renault              4      Renault  2007         51.0
# 734       Dutch         spyker             12       Spyker  2007          1.0
# 735    Japanese    super_aguri              8  Super Aguri  2007          4.0
# 736     Italian     toro_rosso              5   Toro Rosso  2007          8.0
# 737    Japanese         toyota              7       Toyota  2007         13.0
# 738     British       williams              3     Williams  2007         33.0

# %% [markdown]
# > **Which Driver is the Best over the Eras of F1**

# %%
drivers_joined = (drivers >> left_join(driver_standings, by='driverId'))
drivers_joined.head(10)
# Out:
#    driverId driverRef  number code forename   surname         dob nationality  \
# 0         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 1         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 2         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 3         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 4         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 5         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 6         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 7         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 8         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
# 9         1  hamilton    44.0  HAM    Lewis  Hamilton  1985-01-07     British
#
#                                            url  driverStandingsId  raceId  \
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton                1.0    18.0
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton                9.0    19.0
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton               27.0    20.0
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton               48.0    21.0
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton               69.0    22.0
# 5  http://en.wikipedia.org/wiki/Lewis_Hamilton               91.0    23.0
# 6  http://en.wikipedia.org/wiki/Lewis_Hamilton              113.0    24.0
# 7  http://en.wikipedia.org/wiki/Lewis_Hamilton              135.0    25.0
# 8  http://en.wikipedia.org/wiki/Lewis_Hamilton              157.0    26.0
# 9  http://en.wikipedia.org/wiki/Lewis_Hamilton              179.0    27.0
#
#    points  position positionText  wins
# 0    10.0       1.0            1   1.0
# 1    14.0       1.0            1   1.0
# 2    14.0       3.0            3   1.0
# 3    20.0       2.0            2   1.0
# 4    28.0       3.0            3   1.0
# 5    38.0       1.0            1   2.0
# 6    38.0       2.0            2   2.0
# 7    38.0       4.0            4   2.0
# 8    48.0       1.0            1   3.0
# 9    58.0       1.0            1   4.0

# %%
drivers_cleaned = (drivers_joined
                    >> drop(X.dob, X.url, X.driverRef)
)
drivers_cleaned.head(8)
# Out:
#    driverId  number code forename   surname nationality  driverStandingsId  \
# 0         1    44.0  HAM    Lewis  Hamilton     British                1.0
# 1         1    44.0  HAM    Lewis  Hamilton     British                9.0
# 2         1    44.0  HAM    Lewis  Hamilton     British               27.0
# 3         1    44.0  HAM    Lewis  Hamilton     British               48.0
# 4         1    44.0  HAM    Lewis  Hamilton     British               69.0
# 5         1    44.0  HAM    Lewis  Hamilton     British               91.0
# 6         1    44.0  HAM    Lewis  Hamilton     British              113.0
# 7         1    44.0  HAM    Lewis  Hamilton     British              135.0
#
#    raceId  points  position positionText  wins
# 0    18.0    10.0       1.0            1   1.0
# 1    19.0    14.0       1.0            1   1.0
# 2    20.0    14.0       3.0            3   1.0
# 3    21.0    20.0       2.0            2   1.0
# 4    22.0    28.0       3.0            3   1.0
# 5    23.0    38.0       1.0            1   2.0
# 6    24.0    38.0       2.0            2   2.0
# 7    25.0    38.0       4.0            4   2.0

# %%
drivers_races = (drivers_cleaned >> left_join(races, by='raceId'))
drivers_races.columns
# Out:
# Index(['driverId', 'number', 'code', 'forename', 'surname', 'nationality',
#        'driverStandingsId', 'raceId', 'points', 'position', 'positionText',
#        'wins', 'year', 'round', 'circuitId', 'name', 'date', 'time', 'url',
#        'fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
#        'quali_date', 'quali_time', 'sprint_date', 'sprint_time'],
#       dtype='object')

# %%
drivers_cleaned2 = (drivers_races
                    >> drop(X.fp1_time, X.fp1_date, X.fp2_date, X.fp2_time, X.fp3_date, X.fp3_time, X.quali_date, X.quali_time, X.url, 
                            X.sprint_date, X.sprint_time)
                    >> mutate(year = split_and_get('-', 0))
                    >> drop(X.date, X.number)
                    >> group_by(X.driverId, X.raceId)
)
drivers_cleaned2.head(5)
# Out:
#    driverId code forename   surname nationality  driverStandingsId  raceId  \
# 0         1  HAM    Lewis  Hamilton     British                1.0    18.0
# 1         1  HAM    Lewis  Hamilton     British                9.0    19.0
# 2         1  HAM    Lewis  Hamilton     British               27.0    20.0
# 3         1  HAM    Lewis  Hamilton     British               48.0    21.0
# 4         1  HAM    Lewis  Hamilton     British               69.0    22.0
#
#    points  position positionText  wins  year  round  circuitId  \
# 0    10.0       1.0            1   1.0  2008    1.0        1.0
# 1    14.0       1.0            1   1.0  2008    2.0        2.0
# 2    14.0       3.0            3   1.0  2008    3.0        3.0
# 3    20.0       2.0            2   1.0  2008    4.0        4.0
# 4    28.0       3.0            3   1.0  2008    5.0        5.0
#
#                     name      time
# 0  Australian Grand Prix  04:30:00
# 1   Malaysian Grand Prix  07:00:00
# 2     Bahrain Grand Prix  11:30:00
# 3     Spanish Grand Prix  12:00:00
# 4     Turkish Grand Prix  12:00:00

# %%
drivers_results = (drivers_cleaned2 >> inner_join(results, by=['raceId', 'driverId']))
drivers_results.head(8)
# Out:
#    driverId code forename   surname nationality  driverStandingsId  raceId  \
# 0         1  HAM    Lewis  Hamilton     British                1.0    18.0
# 1         1  HAM    Lewis  Hamilton     British                9.0    19.0
# 2         1  HAM    Lewis  Hamilton     British               27.0    20.0
# 3         1  HAM    Lewis  Hamilton     British               48.0    21.0
# 4         1  HAM    Lewis  Hamilton     British               69.0    22.0
# 5         1  HAM    Lewis  Hamilton     British               91.0    23.0
# 6         1  HAM    Lewis  Hamilton     British              113.0    24.0
# 7         1  HAM    Lewis  Hamilton     British              135.0    25.0
#
#    points_x  position_x positionText_x  ...  positionOrder points_y  laps  \
# 0      10.0         1.0              1  ...              1     10.0    58
# 1      14.0         1.0              1  ...              5      4.0    56
# 2      14.0         3.0              3  ...             13      0.0    56
# 3      20.0         2.0              2  ...              3      6.0    66
# 4      28.0         3.0              3  ...              2      8.0    58
# 5      38.0         1.0              1  ...              1     10.0    76
# 6      38.0         2.0              2  ...             19      0.0    19
# 7      38.0         4.0              4  ...             10      0.0    70
#
#         time_y milliseconds fastestLap  rank  fastestLapTime  fastestLapSpeed  \
# 0  1:34:50.616    5690616.0       39.0   2.0        1:27.452          218.300
# 1      +46.548    5525103.0       53.0   3.0        1:35.462          209.033
# 2          NaN          NaN       25.0  19.0        1:35.520          203.969
# 3       +4.187    5903238.0       20.0   3.0        1:22.017          204.323
# 4       +3.779    5213230.0       31.0   2.0        1:26.529          222.085
# 5  2:00:42.742    7242742.0       71.0   6.0        1:18.510          153.152
# 6          NaN          NaN        4.0   3.0        1:17.506          202.559
# 7      +54.538    5564783.0       40.0   5.0        1:17.453          205.022
#
#    statusId
# 0         1
# 1         1
# 2        11
# 3         1
# 4         1
# 5         1
# 6         4
# 7         1
#
# [8 rows x 32 columns]

# %%
drivers_results_cols = (drivers_results.rename(columns={"points_x":"running_season_total", "points_y":"race_points", "time_x":"time_of_race", 
                        "time_y":"race_time", "name":"circuit_name", "positionText_x":"season_position", 
                        "positionText_y":"race_position", "forename":"fname", "surname":"lname", "round":"race_round"})
                        )
drivers_results_cols.head(8)
# Out:
#    driverId code  fname     lname nationality  driverStandingsId  raceId  \
# 0         1  HAM  Lewis  Hamilton     British                1.0    18.0
# 1         1  HAM  Lewis  Hamilton     British                9.0    19.0
# 2         1  HAM  Lewis  Hamilton     British               27.0    20.0
# 3         1  HAM  Lewis  Hamilton     British               48.0    21.0
# 4         1  HAM  Lewis  Hamilton     British               69.0    22.0
# 5         1  HAM  Lewis  Hamilton     British               91.0    23.0
# 6         1  HAM  Lewis  Hamilton     British              113.0    24.0
# 7         1  HAM  Lewis  Hamilton     British              135.0    25.0
#
#    running_season_total  position_x season_position  ...  positionOrder  \
# 0                  10.0         1.0               1  ...              1
# 1                  14.0         1.0               1  ...              5
# 2                  14.0         3.0               3  ...             13
# 3                  20.0         2.0               2  ...              3
# 4                  28.0         3.0               3  ...              2
# 5                  38.0         1.0               1  ...              1
# 6                  38.0         2.0               2  ...             19
# 7                  38.0         4.0               4  ...             10
#
#   race_points  laps    race_time milliseconds fastestLap  rank  \
# 0        10.0    58  1:34:50.616    5690616.0       39.0   2.0
# 1         4.0    56      +46.548    5525103.0       53.0   3.0
# 2         0.0    56          NaN          NaN       25.0  19.0
# 3         6.0    66       +4.187    5903238.0       20.0   3.0
# 4         8.0    58       +3.779    5213230.0       31.0   2.0
# 5        10.0    76  2:00:42.742    7242742.0       71.0   6.0
# 6         0.0    19          NaN          NaN        4.0   3.0
# 7         0.0    70      +54.538    5564783.0       40.0   5.0
#
#    fastestLapTime  fastestLapSpeed  statusId
# 0        1:27.452          218.300         1
# 1        1:35.462          209.033         1
# 2        1:35.520          203.969        11
# 3        1:22.017          204.323         1
# 4        1:26.529          222.085         1
# 5        1:18.510          153.152         1
# 6        1:17.506          202.559         4
# 7        1:17.453          205.022         1
#
# [8 rows x 32 columns]

# %%
drivers_results_cleaning = (drivers_results_cols
            >> drop(X.position_y, X.position_x, X.positionOrder, X['rank'], X['number'], X['grid'], X.resultId, X.driverStandingsId, X.milliseconds)
) 
drivers_results_cleaning.head(10)
# Out:
#    driverId code  fname     lname nationality  raceId  running_season_total  \
# 0         1  HAM  Lewis  Hamilton     British    18.0                  10.0
# 1         1  HAM  Lewis  Hamilton     British    19.0                  14.0
# 2         1  HAM  Lewis  Hamilton     British    20.0                  14.0
# 3         1  HAM  Lewis  Hamilton     British    21.0                  20.0
# 4         1  HAM  Lewis  Hamilton     British    22.0                  28.0
# 5         1  HAM  Lewis  Hamilton     British    23.0                  38.0
# 6         1  HAM  Lewis  Hamilton     British    24.0                  38.0
# 7         1  HAM  Lewis  Hamilton     British    25.0                  38.0
# 8         1  HAM  Lewis  Hamilton     British    26.0                  48.0
# 9         1  HAM  Lewis  Hamilton     British    27.0                  58.0
#
#   season_position  wins  year  ...  time_of_race  constructorId race_position  \
# 0               1   1.0  2008  ...      04:30:00              1             1
# 1               1   1.0  2008  ...      07:00:00              1             5
# 2               3   1.0  2008  ...      11:30:00              1            13
# 3               2   1.0  2008  ...      12:00:00              1             3
# 4               3   1.0  2008  ...      12:00:00              1             2
# 5               1   2.0  2008  ...      12:00:00              1             1
# 6               2   2.0  2008  ...      17:00:00              1             R
# 7               4   2.0  2008  ...      12:00:00              1            10
# 8               1   3.0  2008  ...      12:00:00              1             1
# 9               1   4.0  2008  ...      12:00:00              1             1
#
#   race_points  laps    race_time  fastestLap  fastestLapTime fastestLapSpeed  \
# 0        10.0    58  1:34:50.616        39.0        1:27.452         218.300
# 1         4.0    56      +46.548        53.0        1:35.462         209.033
# 2         0.0    56          NaN        25.0        1:35.520         203.969
# 3         6.0    66       +4.187        20.0        1:22.017         204.323
# 4         8.0    58       +3.779        31.0        1:26.529         222.085
# 5        10.0    76  2:00:42.742        71.0        1:18.510         153.152
# 6         0.0    19          NaN         4.0        1:17.506         202.559
# 7         0.0    70      +54.538        40.0        1:17.453         205.022
# 8        10.0    60  1:39:09.440        16.0        1:32.817         199.398
# 9        10.0    67  1:31:20.874        17.0        1:16.039         216.552
#
#    statusId
# 0         1
# 1         1
# 2        11
# 3         1
# 4         1
# 5         1
# 6         4
# 7         1
# 8         1
# 9         1
#
# [10 rows x 23 columns]

# %%
drivers_status = (drivers_results_cleaning >> left_join(status, by='statusId'))
drivers_status.head(5)
# Out:
#    driverId code  fname     lname nationality  raceId  running_season_total  \
# 0         1  HAM  Lewis  Hamilton     British    18.0                  10.0
# 1         1  HAM  Lewis  Hamilton     British    19.0                  14.0
# 2         1  HAM  Lewis  Hamilton     British    20.0                  14.0
# 3         1  HAM  Lewis  Hamilton     British    21.0                  20.0
# 4         1  HAM  Lewis  Hamilton     British    22.0                  28.0
#
#   season_position  wins  year  ...  constructorId  race_position race_points  \
# 0               1   1.0  2008  ...              1              1        10.0
# 1               1   1.0  2008  ...              1              5         4.0
# 2               3   1.0  2008  ...              1             13         0.0
# 3               2   1.0  2008  ...              1              3         6.0
# 4               3   1.0  2008  ...              1              2         8.0
#
#   laps    race_time fastestLap  fastestLapTime  fastestLapSpeed statusId  \
# 0   58  1:34:50.616       39.0        1:27.452          218.300        1
# 1   56      +46.548       53.0        1:35.462          209.033        1
# 2   56          NaN       25.0        1:35.520          203.969       11
# 3   66       +4.187       20.0        1:22.017          204.323        1
# 4   58       +3.779       31.0        1:26.529          222.085        1
#
#      status
# 0  Finished
# 1  Finished
# 2    +1 Lap
# 3  Finished
# 4  Finished
#
# [5 rows x 24 columns]

# %%
drivers_status.columns
# Out:
# Index(['driverId', 'code', 'fname', 'lname', 'nationality', 'raceId',
#        'running_season_total', 'season_position', 'wins', 'year', 'race_round',
#        'circuitId', 'circuit_name', 'time_of_race', 'constructorId',
#        'race_position', 'race_points', 'laps', 'race_time', 'fastestLap',
#        'fastestLapTime', 'fastestLapSpeed', 'statusId', 'status'],
#       dtype='object')

# %%
personalmax = (drivers_status
        >> group_by(X.driverId, X.fname, X.lname, X.nationality, X.year)
        >> summarize(maxdrive = X.running_season_total.max())
)
personalmax.head(5)
# Out:
#    year nationality     lname  fname  driverId  maxdrive
# 0  2007     British  Hamilton  Lewis         1     109.0
# 1  2008     British  Hamilton  Lewis         1      98.0
# 2  2009     British  Hamilton  Lewis         1      49.0
# 3  2010     British  Hamilton  Lewis         1     240.0
# 4  2011     British  Hamilton  Lewis         1     227.0

# %%
mostdriverpoint = (drivers_status
            >> group_by(X.year)
            >> summarize(drivermax = X.running_season_total.max())
)
mostdriverpoint.head(5)
# Out:
#    year  drivermax
# 0  1950       30.0
# 1  1951       31.0
# 2  1952       36.0
# 3  1953       34.5
# 4  1954       42.0

# %%
pd.set_option('display.max_rows', False) #None if max rows wanted

driver_max_join = (personalmax >> inner_join(mostdriverpoint,by='year'))
driver_championships = (driver_max_join
             >> mutate(driverpercent = X.maxdrive/X.drivermax)
             >> filter_by(X.driverpercent==1)
             >> arrange(X.year, ascending = True)
            #  >> drop(X.constructorId, X.team_percents, X.maxpoints)
)
driver_championships
# Out:
#       year nationality       lname    fname  driverId  maxdrive  drivermax  \
# 2693  1950     Italian      Farina     Nino       642      30.0       30.0
# 2762  1951   Argentine      Fangio     Juan       579      31.0       31.0
# 2869  1952     Italian      Ascari  Alberto       647      36.0       36.0
# 2989  1953     Italian      Ascari  Alberto       647      34.5       34.5
# 3076  1954   Argentine      Fangio     Juan       579      42.0       42.0
# 2618  1955   Argentine      Fangio     Juan       579      40.0       40.0
# 2466  1956   Argentine      Fangio     Juan       579      30.0       30.0
# 2558  1957   Argentine      Fangio     Juan       579      40.0       40.0
# 2095  1958     British    Hawthorn     Mike       578      42.0       42.0
# ...    ...         ...         ...      ...       ...       ...        ...
# 175   2014     British    Hamilton    Lewis         1     384.0      384.0
# 199   2015     British    Hamilton    Lewis         1     381.0      381.0
# 222   2016      German     Rosberg     Nico         3     385.0      385.0
# 245   2017     British    Hamilton    Lewis         1     363.0      363.0
# 270   2018     British    Hamilton    Lewis         1     408.0      408.0
# 290   2019     British    Hamilton    Lewis         1     413.0      413.0
# 310   2020     British    Hamilton    Lewis         1     347.0      347.0
# 341   2021       Dutch  Verstappen      Max       830     395.5      395.5
# 362   2022       Dutch  Verstappen      Max       830     258.0      258.0
#
#       driverpercent
# 2693            1.0
# 2762            1.0
# 2869            1.0
# 2989            1.0
# 3076            1.0
# 2618            1.0
# 2466            1.0
# 2558            1.0
# 2095            1.0
# ...             ...
# 175             1.0
# 199             1.0
# 222             1.0
# 245             1.0
# 270             1.0
# 290             1.0
# 310             1.0
# 341             1.0
# 362             1.0
#
# [73 rows x 8 columns]

# %%
driver_count_championships = (driver_championships
                    >> group_by(X.fname, X.lname, X.driverId)
                    >> summarize(championships = X.driverId.count())
                    >> ungroup
                    >> arrange(X.championships, ascending = False)
                    >> filter_by(X.championships > 1)
)
driver_count_championships
# Out:
#     driverId       lname      fname  championships
# 24        30  Schumacher    Michael              7
# 21         1    Hamilton      Lewis              7
# 18       579      Fangio       Juan              5
# 0        117       Prost      Alain              4
# 33        20      Vettel  Sebastian              4
# 3        102       Senna     Ayrton              3
# 9        356     Brabham       Jack              3
# 10       328     Stewart     Jackie              3
# 27       137      Piquet     Nelson              3
# 30       182       Lauda       Niki              3
# 14       373       Clark        Jim              2
# 23       830  Verstappen        Max              2
# 25        57    Häkkinen       Mika              2
# 6        224  Fittipaldi    Emerson              2
# 2        647      Ascari    Alberto              2
# 8        289        Hill     Graham              2
# 7          4      Alonso   Fernando              2

# %%
bestdrivers = (driver_count_championships
    >> filter_by(X.championships > 3)
)
bestdrivers
# Out:
#     driverId       lname      fname  championships
# 24        30  Schumacher    Michael              7
# 21         1    Hamilton      Lewis              7
# 18       579      Fangio       Juan              5
# 0        117       Prost      Alain              4
# 33        20      Vettel  Sebastian              4

# %%
remove_decimal = lambda x: x.replace('.0', '')

# %%
topdriver_select = (drivers_status
                >> mutate(driverId = X.driverId.astype(str))
                >> mutate(raceId = X.raceId.astype(str).apply(remove_decimal))
                # >> filter_by((X.driverId == '30')|(X.driverId == '1')|(X.driverId=='579')|(X.driverId=='579')|(X.driverId=='117')|(X.driverId=='20'))
)
topdriver_select.head(10)
# Out:
#   driverId code  fname     lname nationality raceId  running_season_total  \
# 0        1  HAM  Lewis  Hamilton     British     18                  10.0
# 1        1  HAM  Lewis  Hamilton     British     19                  14.0
# 2        1  HAM  Lewis  Hamilton     British     20                  14.0
# 3        1  HAM  Lewis  Hamilton     British     21                  20.0
# 4        1  HAM  Lewis  Hamilton     British     22                  28.0
# 5        1  HAM  Lewis  Hamilton     British     23                  38.0
# 6        1  HAM  Lewis  Hamilton     British     24                  38.0
# 7        1  HAM  Lewis  Hamilton     British     25                  38.0
# 8        1  HAM  Lewis  Hamilton     British     26                  48.0
# 9        1  HAM  Lewis  Hamilton     British     27                  58.0
#
#   season_position  wins  year  ...  constructorId  race_position race_points  \
# 0               1   1.0  2008  ...              1              1        10.0
# 1               1   1.0  2008  ...              1              5         4.0
# 2               3   1.0  2008  ...              1             13         0.0
# 3               2   1.0  2008  ...              1              3         6.0
# 4               3   1.0  2008  ...              1              2         8.0
# 5               1   2.0  2008  ...              1              1        10.0
# 6               2   2.0  2008  ...              1              R         0.0
# 7               4   2.0  2008  ...              1             10         0.0
# 8               1   3.0  2008  ...              1              1        10.0
# 9               1   4.0  2008  ...              1              1        10.0
#
#   laps    race_time fastestLap  fastestLapTime  fastestLapSpeed statusId  \
# 0   58  1:34:50.616       39.0        1:27.452          218.300        1
# 1   56      +46.548       53.0        1:35.462          209.033        1
# 2   56          NaN       25.0        1:35.520          203.969       11
# 3   66       +4.187       20.0        1:22.017          204.323        1
# 4   58       +3.779       31.0        1:26.529          222.085        1
# 5   76  2:00:42.742       71.0        1:18.510          153.152        1
# 6   19          NaN        4.0        1:17.506          202.559        4
# 7   70      +54.538       40.0        1:17.453          205.022        1
# 8   60  1:39:09.440       16.0        1:32.817          199.398        1
# 9   67  1:31:20.874       17.0        1:16.039          216.552        1
#
#       status
# 0   Finished
# 1   Finished
# 2     +1 Lap
# 3   Finished
# 4   Finished
# 5   Finished
# 6  Collision
# 7   Finished
# 8   Finished
# 9   Finished
#
# [10 rows x 24 columns]

# %%
investigate = (drivers_status
        >> group_by(X.status)
        >> filter_by((X.race_position != "R") & (X.statusId != 1)) #this one is weird the cases where the status is everything but 1 (finished) there is an R in
)
investigate.head(10)
# Out:
#      driverId code  fname     lname nationality  raceId  running_season_total  \
# 2           1  HAM  Lewis  Hamilton     British    20.0                  14.0
# 28          1  HAM  Lewis  Hamilton     British    45.0                  70.0
# 35          1  HAM  Lewis  Hamilton     British    52.0                 109.0
# 39          1  HAM  Lewis  Hamilton     British     5.0                   9.0
# 40          1  HAM  Lewis  Hamilton     British     6.0                   9.0
# 42          1  HAM  Lewis  Hamilton     British     8.0                   9.0
# 43          1  HAM  Lewis  Hamilton     British     9.0                   9.0
# 114         1  HAM  Lewis  Hamilton     British   884.0                  50.0
# 204         1  HAM  Lewis  Hamilton     British   986.0                 333.0
# 290         1  HAM  Lewis  Hamilton     British  1077.0                  28.0
#
#     season_position  wins  year  ...  constructorId  race_position  \
# 2                 3   1.0  2008  ...              1             13
# 28                1   2.0  2007  ...              1              9
# 35                2   4.0  2007  ...              1              7
# 39                7   0.0  2009  ...              1              9
# 40                9   0.0  2009  ...              1             12
# 42               11   0.0  2009  ...              1             16
# 43               11   0.0  2009  ...              1             18
# 114               4   0.0  2013  ...            131             12
# 204               1   9.0  2017  ...            131              9
# 290               7   0.0  2022  ...            131             13
#
#     race_points laps  race_time fastestLap  fastestLapTime  fastestLapSpeed  \
# 2           0.0   56        NaN       25.0        1:35.520          203.969
# 28          0.0   59        NaN       29.0        1:33.401          198.421
# 35          2.0   70        NaN       58.0        1:12.506          213.946
# 39          0.0   65        NaN       29.0        1:23.839          199.883
# 40          0.0   77        NaN       65.0        1:15.706          158.824
# 42          0.0   59        NaN       24.0        1:22.576          224.128
# 43          0.0   59        NaN       46.0        1:35.367          194.331
# 114         0.0   65        NaN       53.0        1:27.895          190.659
# 204         2.0   70        NaN       69.0        1:19.945          193.813
# 290         0.0   62        NaN       50.0        1:21.419          217.054
#
#     statusId  status
# 2         11  +1 Lap
# 28        11  +1 Lap
# 35        11  +1 Lap
# 39        11  +1 Lap
# 40        11  +1 Lap
# 42        11  +1 Lap
# 43        11  +1 Lap
# 114       11  +1 Lap
# 204       11  +1 Lap
# 290       11  +1 Lap
#
# [10 rows x 24 columns]

# %%
positionselect = (topdriver_select
            >> select(X.raceId, X.driverId, X.race_position, X.race_round, X.circuitId, X.year)
            >> filter_by(text_filter(X.race_position, '[^A-Z]', regex=True))
            >> mutate(race_position = X.race_position.astype(int))
            >> mutate(raceId = X.raceId.astype(str).apply(remove_decimal))
)
positionselect.head(10)
# Out:
#    raceId driverId  race_position  race_round  circuitId  year
# 0      18        1              1         1.0        1.0  2008
# 1      19        1              5         2.0        2.0  2008
# 2      20        1             13         3.0        3.0  2008
# 3      21        1              3         4.0        4.0  2008
# 4      22        1              2         5.0        5.0  2008
# 5      23        1              1         6.0        6.0  2008
# 7      25        1             10         8.0        8.0  2008
# 8      26        1              1         9.0        9.0  2008
# 9      27        1              1        10.0       10.0  2008
# 10     28        1              5        11.0       11.0  2008

# %%
positionselect.dtypes
# Out:
# raceId            object
# driverId          object
# race_position      int64
# race_round       float64
# circuitId        float64
# year              object
# dtype: object

# %%
statusrecode = {'Finished':'finished', '+1 Lap':'extra laps 5 or less', 'Collision':'driver/circuit', 'Spun off':'driver/circuit', 'Accident':'driver/circuit',
       'Brakes':'constructor_error', 'Puncture':'constructor_error', 'Gearbox':'constructor_error', 'Electrical':'constructor_error', 'Engine':'constructor_error', 
       'Retired':'other','Throttle':'constructor_error', 'Fuel pressure':'constructor_error', '+4 Laps':'extra laps 5 or less', 'Transmission':'constructor_error',
       'Technical':'constructor_error', '+2 Laps':'extra laps 5 or less', 'Withdrew':'Withdrew', 'Tyre':'constructor_error', 'Driveshaft':'constructor_error',
       'Hydraulics':'constructor_error', 'Handling':'constructor_error', 'Clutch':'constructor_error', '+3 Laps':'constructor_error', 'Alternator':'constructor_error',
       'Suspension':'constructor_error', 'Out of fuel':'constructor_error', 'Heat shield fire':'constructor_error', 'Water leak':'constructor_error',
       'Electronics':'constructor_error', 'Wheel':'constructor_error', 'ERS':'constructor_error', '+6 Laps':'extra laps 6 to 10', 'Battery':'constructor_error',
       'Vibrations':'constructor_error', 'Power Unit':'constructor_error', 'Collision damage':'driver_error', 'Exhaust':'constructor_error', 'Rear wing':'constructor_error',
       'Water pump':'constructor_error', '+10 Laps':'extra laps 6 to 10', 'Steering':'driver_error', 'Oil pressure':'constructor_error', 'Pneumatics':'constructor_error',
       'Wheel rim':'constructor_error', '+5 Laps':'extra laps 5 or less', 'Halfshaft':'constructor_error', 'Differential':'constructor_error', 'Brake duct':'constructor_error',
       'Water pressure':'constructor_error', 'Turbo':'driver_error', 'Power loss':'constructor_error', 'Overheating':'constructor_error', 'Oil leak':'constructor_error',
       'Driver Seat':'constructor_error', 'Injured':'driver_error', 'Track rod':'constructor_error', 'Mechanical':'constructor_error', '+9 Laps':'extra laps 6 to 10',
       '+17 Laps':'extra laps 16+', 'Disqualified':'DQ', '+7 Laps':'extra laps 6 to 10', 'Excluded':'driver_error', 'Wheel nut':'constructor_error',
       '+12 Laps':'extra laps 11 to 15', '+26 Laps':'extra laps 16+', 'Safety':'other', 'Fuel':'constructor_error', 'Radiator':'constructor_error',
       'Spark plugs':'constructor_error', '+8 Laps':'extra laps 6 to 10', 'Fuel system':'constructor_error', 'Injury':'driver_error', 'Fuel pump':'constructor_error',
       'Ignition':'constructor_error', 'Wheel bearing':'constructor_error', '+11 Laps':'extra laps 11 to 15', 'Front wing':'constructor_error',
       'Refuelling':'constructor_error', 'Broken wing':'constructor_error', 'Chassis':'constructor_error', 'Engine fire':'constructor_error',
       'Not restarted':'driver_error', 'Did not qualify':'driver_error', '+42 Laps':'extra laps 16+', 'Launch control':'constructor_error',
       'Tyre puncture':'constructor_error', 'Fire':'Misc.', 'Oil line':'constructor_error', 'Fuel rig':'constructor_error', 'Stalled':'constructor_error',
       '107% Rule':'constructor_error', 'Underweight':'constructor_error', 'Crankshaft':'constructor_error', 'Drivetrain':'constructor_error',
       'Not classified':'Misc.', 'Physical':'Misc.', 'Oil pump':'constructor_error', 'Injection':'constructor_error',
       'Did not prequalify':'driver_error', 'Fuel leak':'constructor_error', 'Driver unwell':'driver_error', 'CV joint':'constructor_error',
       'Distributor':'constructor_error', 'Fatal accident':'driver/circuit', 'Fuel pipe':'constructor_error', 'Oil pipe':'constructor_error',
       'Axle':'constructor_error',
       'Eye injury':'driver_error', '+25 Laps':'extra laps 16+', '+22 Laps':'extra laps 16+', 'Water pipe':'constructor_error', '+21 Laps':'extra laps 16+',
       '+24 Laps':'extra laps 16+', '+29 Laps':'extra laps 16+', '+14 Laps':'extra laps 11 to 15', '+15 Laps':'extra laps 11 to 15', '+16 Laps':'extra laps 16+',
       '+30 Laps':'extra laps 16+', '+23 Laps':'extra laps 16+', '+44 Laps':'extra laps 16+', '+18 Laps':'extra laps 16+', '+19 Laps':'extra laps 16+',
       '+13 Laps':'extra laps 11 to 15', 'Magneto':'Misc.', '+20 Laps':'extra laps 16+', '+46 Laps':'extra laps 16+', 'Supercharger':'constructor_error',
       'Engine misfire':'constructor_error', 'Seat':'Misc.', 'Damage':'constructor_error', 'Cooling system':'constructor_error', 'Illness':'driver_error',
       'Debris':'driver_error', 'Undertray':'constructor_error'}

# %% [markdown]
# do average but ALSO std dev to measure consistency of laps - look to see visually the speed with consistency
#
# plot of avg lap time vs std dev lap time
#
# logistic model/probability model of top 10 (points drop off after top 10)

# %%
def add_decimal(x):
    return float(str(x)[:-3] + "." + str(x)[-3:])

# %%
lapdrivers_select = (lap_times
        >> mutate(driverId = X.driverId.astype(str))
        >> mutate(raceId = X.raceId.astype(str))
        >> group_by(X.driverId, X.raceId)
        >> mutate(newtime = (X.milliseconds.apply(add_decimal)))
        >> select(~X.time, ~X.milliseconds)
        >> summarize(avg_laptime = X.newtime.mean(), 
                     lap_deviation = X.newtime.std())
        >> ungroup
)
lapdrivers_select.head(5)
# Out:
#   raceId driverId  avg_laptime  lap_deviation
# 0      1        1    97.563759      16.066158
# 1     10        1    84.341086       4.220408
# 2   1000        1    83.377529       3.404940
# 3   1001        1   114.216750      18.541712
# 4   1002        1    87.065736      10.008775

# %%
## only has laptimes for lewis hamilton, michael schumacher, and sebastian vettel - lap times were not recorded for the previous drivers

# when comparing only need the following         
# # >> filter_by((X.driverId == '30')|(X.driverId == '1')|(X.driverId=='579')|(X.driverId=='117')|(X.driverId=='20'))

# %%
str_splitting = lambda x: list(map(float, x.split(':')))
min_to_seconds = (lambda x: (x[0]*60 + x[1]))

# %%
laptimes_joined = topdriver_select >> inner_join(lapdrivers_select, on =['driverId', 'raceId'])
driver_laptimes = (laptimes_joined
                >> select(X.driverId, X.fname, X.lname, X.raceId, X.year, X.laps, X.fastestLapTime, X.fastestLap, X.fastestLapSpeed, X.avg_laptime, X.lap_deviation, X.status)
                >> group_by(X.driverId, X.raceId)
                >> mutate(fastestLapTime = X.fastestLapTime.astype(str))
                >> filter_by(X.fastestLapTime != 'nan')
                >> mutate(fastestLapTime = X.fastestLapTime.apply(str_splitting))
                >> mutate(fastestLapTime = X.fastestLapTime.apply(min_to_seconds))
                >> mutate(status = X.status.map(statusrecode))
                >> mutate(new_statusId = if_else(X.status == 'driver/circuit', 1,0))
)
driver_laptimes.head(5)
# Out:
#     driverId  fname     lname raceId  year  laps  fastestLapTime  fastestLap  \
# 44         1  Lewis  Hamilton     10  2009    70          82.479        16.0
# 214        1  Lewis  Hamilton   1000  2018    70          81.107        63.0
# 215        1  Lewis  Hamilton   1001  2018    44         106.721        23.0
# 216        1  Lewis  Hamilton   1002  2018    53          82.497        30.0
# 217        1  Lewis  Hamilton   1003  2018    61         102.913        56.0
#
#      fastestLapSpeed  avg_laptime  lap_deviation    status  new_statusId
# 44           191.219    84.341086       4.220408  finished             0
# 214          194.454    83.377529       3.404940  finished             0
# 215          236.264   114.216750      18.541712  finished             0
# 216          252.794    87.065736      10.008775  finished             0
# 217          177.108   109.370672      13.740921  finished             0

# %%
driver_laptimes.shape
# Out:
# (7155, 13)

# %% [markdown]
# 1.111111e+61 is likely due to a precision error when adding large numbers.
# This is happening because the x[0]*60 is being treated as a float, and it's too large for the float data type to handle, resulting in a precision loss.

# %% [markdown]
# The error message invalid literal for int() with base 10: '11111111111111111111111111111111111111111111111111111111111139.141' is indicating that the int() function is unable to convert the input value to an integer, because it is not a valid integer literal.
# It looks like the problem is that the input value is a string and not a number, so the int() function is not able to convert it.
#
#
# seems like it was trying to apply this function to a column that is not a list of numbers but a string.
#
# time column is converted to a list of numbers using the list(map(float, x.split(':'))) function. The split(':') function is used to split the string by the colon character, and the map(float,...) function is used to convert the resulting list of strings to a list of numbers. Then, the function to convert the time in seconds is applied to the new list of numbers, and the time column is replaced by the time_in_seconds column and casted to float

# %%
driver_laptimes.dtypes
# Out:
# driverId            object
# fname               object
# lname               object
# raceId              object
# year                object
# laps                 int64
# fastestLapTime     float64
# fastestLap         float64
# fastestLapSpeed    float64
# avg_laptime        float64
# lap_deviation      float64
# status              object
# new_statusId         int64
# dtype: object

# %%
pitstop_times =(pit_stops
        >> mutate(driverId = X.driverId.astype(str))
        >> mutate(raceId = X.raceId.astype(str))
        # >> filter_by((X.driverId == '30')|(X.driverId == '1')|(X.driverId=='579')|(X.driverId=='117')|(X.driverId=='20'))
        >> group_by(X.driverId, X.raceId)
        >> mutate(newtime = (X.milliseconds.apply(add_decimal)))
        >> select(~X.time, ~X.milliseconds)
        >> summarize(avg_pitstop = X.newtime.mean(), 
                     pit_dev = X.newtime.std())
        >> ungroup
)
pitstop_times.head(5)
# Out:
#   raceId driverId  avg_pitstop   pit_dev
# 0   1000        1      21.4800       NaN
# 1   1001        1      20.8735  2.123442
# 2   1002        1      23.7280       NaN
# 3   1003        1      28.9460       NaN
# 4   1004        1      29.5510       NaN

# %% [markdown]
# In Formula 1 racing, the qualifying round is a session held before the main race that determines the starting positions for the race. There are typically three segments to the qualifying round, known as Q1, Q2, and Q3.
#
# During Q1, all drivers are on the track at the same time and have a certain amount of time to set their fastest lap. The slowest drivers are eliminated, and the remaining drivers move on to Q2.
#
# In Q2, the process is repeated, with the slowest drivers being eliminated and the remaining drivers moving on to Q3.
#
# Finally, in Q3, the top ten drivers compete for the pole position, or the first starting spot for the race. The driver who sets the fastest lap time during Q3 will start in the pole position, with the second-fastest driver starting in second place, and so on.
#
# The qualifying round is important because the starting position can have a significant impact on the outcome of the race, as drivers who start at the front of the grid have a better chance of winning the race

# %%
qualify_clean = (qualifying
            >> mutate(raceId = X.raceId.astype(str))
            >> mutate(driverId = X.driverId.astype(str))
            >> mutate(starting_position = X.position)
            >> drop(X.position, X.number, X.qualifyId)
)
qualify_clean.head(5)
# Out:
#   raceId driverId  constructorId        q1        q2        q3  \
# 0     18        1              1  1:26.572  1:25.187  1:26.714
# 1     18        9              2  1:26.103  1:25.315  1:26.869
# 2     18        5              1  1:25.664  1:25.452  1:27.079
# 3     18       13              6  1:25.994  1:25.691  1:27.178
# 4     18        2              2  1:25.960  1:25.518  1:27.236
#
#    starting_position
# 0                  1
# 1                  2
# 2                  3
# 3                  4
# 4                  5

# %%
alltimesjoined = driver_laptimes >> left_join(pitstop_times, on = ['raceId', 'driverId'])
alltimes_positions = alltimesjoined >> left_join(positionselect, on = ['raceId', 'driverId'])
alltimes_qualifying = alltimes_positions >> outer_join(qualify_clean, on = ['raceId','driverId'])
alltimes_qualifying.head(5)
# Out:
#   driverId  fname     lname raceId  year  laps  fastestLapTime  fastestLap  \
# 0        1  Lewis  Hamilton     10  2009  70.0          82.479        16.0
# 1        1  Lewis  Hamilton   1000  2018  70.0          81.107        63.0
# 2        1  Lewis  Hamilton   1001  2018  44.0         106.721        23.0
# 3        1  Lewis  Hamilton   1002  2018  53.0          82.497        30.0
# 4        1  Lewis  Hamilton   1003  2018  61.0         102.913        56.0
#
#    fastestLapSpeed  avg_laptime  ...  avg_pitstop   pit_dev  race_position  \
# 0          191.219    84.341086  ...          NaN       NaN            1.0
# 1          194.454    83.377529  ...      21.4800       NaN            1.0
# 2          236.264   114.216750  ...      20.8735  2.123442            2.0
# 3          252.794    87.065736  ...      23.7280       NaN            1.0
# 4          177.108   109.370672  ...      28.9460       NaN            1.0
#
#    race_round  circuitId  constructorId        q1        q2        q3  \
# 0        10.0       11.0            1.0  1:20.842  1:20.465  1:21.839
# 1        12.0       11.0          131.0  1:17.419  1:31.242  1:35.658
# 2        13.0       13.0          131.0  1:42.977  1:41.553  1:58.179
# 3        14.0       14.0          131.0  1:20.810  1:19.798  1:19.294
# 4        15.0       15.0          131.0  1:39.403  1:37.344  1:36.015
#
#   starting_position
# 0               4.0
# 1               1.0
# 2               1.0
# 3               3.0
# 4               1.0
#
# [5 rows x 23 columns]

# %%
alltimes_qualifying.columns
# Out:
# Index(['driverId', 'fname', 'lname', 'raceId', 'year', 'laps',
#        'fastestLapTime', 'fastestLap', 'fastestLapSpeed', 'avg_laptime',
#        'lap_deviation', 'status', 'new_statusId', 'avg_pitstop', 'pit_dev',
#        'race_position', 'race_round', 'circuitId', 'constructorId', 'q1', 'q2',
#        'q3', 'starting_position'],
#       dtype='object')

# %%
alltimes_qualifying.year.unique()
# Out:
# array(['2009', '2018', '2019', '2020', '2021', '2022', '2008', '2010',
#        '2007', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2004', '2006', '2005', nan], dtype=object)

# %%
# alltimes_qualifying.to_csv('./data/alltimes_qualifying.csv')

# %% [markdown]
# for the following code only years have data only in 2004 and on up :/ - some drivers lap time, pit stop time, and qualifier information wasn't recorded until late 2000's/early 2010's

# %%
driver_thing = (drivers
            >> select(X.driverId, X.forename, X.surname)
            >> mutate(driverName = X.forename + ' ' + X.surname)
            >> drop(X.forename, X.surname)
)

lap_thing = (results
            >> select(X.raceId, X.driverId, X.positionOrder)
            >> mutate(finish_position = X.positionOrder)
            >> drop(X.positionOrder)
)

lap_drive_join = driver_thing >> inner_join(lap_thing, on = 'driverId')
lap_drive_join
# Out:
#        driverId      driverName  raceId  finish_position
# 0             1  Lewis Hamilton      18                1
# 1             1  Lewis Hamilton      19                5
# 2             1  Lewis Hamilton      20               13
# 3             1  Lewis Hamilton      21                3
# 4             1  Lewis Hamilton      22                2
# 5             1  Lewis Hamilton      23                1
# 6             1  Lewis Hamilton      24               19
# 7             1  Lewis Hamilton      25               10
# 8             1  Lewis Hamilton      26                1
# ...         ...             ...     ...              ...
# 25651       855     Guanyu Zhou    1078               20
# 25652       855     Guanyu Zhou    1079               19
# 25653       855     Guanyu Zhou    1080               16
# 25654       855     Guanyu Zhou    1081               18
# 25655       855     Guanyu Zhou    1082                8
# 25656       855     Guanyu Zhou    1083               19
# 25657       855     Guanyu Zhou    1084               14
# 25658       855     Guanyu Zhou    1085               16
# 25659       855     Guanyu Zhou    1086               13
#
# [25660 rows x 4 columns]

# %%
races_thing = (races
        >> select(X.raceId, X.year)
)
qualifying_thing = (qualifying
            >> select(X.raceId, X.position, X.driverId)
            >> mutate(start_position = X.position)
            >> drop(X.position)
)

race_qual_join = races_thing >> inner_join(qualifying_thing, on = 'raceId')
race_qual_join
# Out:
#       raceId  year  driverId  start_position
# 0          1  2009        18               1
# 1          1  2009        22               2
# 2          1  2009        20               3
# 3          1  2009         9               4
# 4          1  2009         3               5
# 5          1  2009        10               6
# 6          1  2009        13               7
# 7          1  2009        15               8
# 8          1  2009         8               9
# ...      ...   ...       ...             ...
# 9386    1086  2022       855              12
# 9387    1086  2022       825              13
# 9388    1086  2022       840              14
# 9389    1086  2022       854              15
# 9390    1086  2022       852              16
# 9391    1086  2022       848              17
# 9392    1086  2022        20              18
# 9393    1086  2022       842              19
# 9394    1086  2022       849              20
#
# [9395 rows x 4 columns]

# %%
races_quals_join = race_qual_join >> inner_join(lap_drive_join, on = ['raceId', 'driverId'])
drivers_to_1994 = (races_quals_join 
                   >> filter_by(X.year < 2004)
                   >> group_by(X.year, X.driverId, X.driverName)
                   >> summarize(avg_starting_position = mean(X.start_position),
                                avg_finish_position = mean(X.finish_position))
                   >> ungroup
                   >> mutate(year = X.year.astype(str))
                   >> mutate(driverId = X.driverId.astype(str))
)
drivers_to_1994.head(5)
# Out:
#               driverName driverId  year  avg_starting_position  \
# 0        David Coulthard       14  1994               5.625000
# 1     Rubens Barrichello       22  1994               9.333333
# 2     Michael Schumacher       30  1994               1.846154
# 3          Olivier Panis       44  1994              15.133333
# 4  Heinz-Harald Frentzen       49  1994               8.733333
#
#    avg_finish_position
# 0             8.375000
# 1            12.066667
# 2             5.615385
# 3            10.000000
# 4            14.000000

# %%
drivers_to_1994.dtypes
# Out:
# driverName                object
# driverId                  object
# year                      object
# avg_starting_position    float64
# avg_finish_position      float64
# dtype: object

# %%
driverId_string = (driver_championships
                >> mutate(driverId = X.driverId.astype(str))
)
driverId_string.head(5)
# Out:
#       year nationality   lname    fname driverId  maxdrive  drivermax  \
# 2693  1950     Italian  Farina     Nino      642      30.0       30.0
# 2762  1951   Argentine  Fangio     Juan      579      31.0       31.0
# 2869  1952     Italian  Ascari  Alberto      647      36.0       36.0
# 2989  1953     Italian  Ascari  Alberto      647      34.5       34.5
# 3076  1954   Argentine  Fangio     Juan      579      42.0       42.0
#
#       driverpercent
# 2693            1.0
# 2762            1.0
# 2869            1.0
# 2989            1.0
# 3076            1.0

# %%
driver_avg_pos = (alltimes_qualifying
                >> select(X.driverId, X.year, X.constructorId, X.starting_position, X.race_position)
                >> group_by(X.year, X.driverId, X.constructorId)
                >> summarize(avg_starting_position = mean(X.starting_position),
                             avg_finish_position = mean(X.race_position))
                >> ungroup
                >> mutate(constructorId = X.constructorId.astype(str))
                >> mutate(constructorId = X.constructorId.apply(remove_decimal))
)
driver_avg_pos.head(5)
# Out:
#   constructorId driverId  year  avg_starting_position  avg_finish_position
# 0            17       10  2004              17.000000            13.000000
# 1            16       11  2004               7.294118             7.538462
# 2            15       13  2004              13.687500             9.214286
# 3             1       14  2004               9.555556             7.714286
# 4             4       15  2004               6.928571             5.583333

# %%
position_champion_join = driverId_string >> inner_join(driver_avg_pos, on = ['year', 'driverId'])
# constructor_with_driver = position_champion_join >> inner_join(constructor_champions, on = ['constructorId', 'year'])
# constructor_with_driver
position_champion_join.head(5)
# Out:
#    year nationality       lname     fname driverId  maxdrive  drivermax  \
# 0  2004      German  Schumacher   Michael       30     148.0      148.0
# 1  2005     Spanish      Alonso  Fernando        4     133.0      133.0
# 2  2006     Spanish      Alonso  Fernando        4     134.0      134.0
# 3  2007     Finnish   Räikkönen      Kimi        8     110.0      110.0
# 4  2008     British    Hamilton     Lewis        1      98.0       98.0
#
#    driverpercent constructorId  avg_starting_position  avg_finish_position
# 0            1.0             6               3.444444             2.117647
# 1            1.0             4               3.944444             2.411765
# 2            1.0             4               4.333333             1.937500
# 3            1.0             6               3.588235             2.600000
# 4            1.0             1               3.055556             4.411765

# %%
champion_avg_position = (position_champion_join
                    >> select(X.year, X.fname, X.lname, X.driverId, X.avg_starting_position, X.constructorId, X.avg_finish_position)
                    >> mutate(driverName = X.fname + ' ' + X.lname)
                    >> select(X.year, X.driverId, X.constructorId, X.driverName, X.avg_starting_position, X.avg_finish_position)
)
champion_avg_position.head(5)
# Out:
#    year driverId constructorId          driverName  avg_starting_position  \
# 0  2004       30             6  Michael Schumacher               3.444444
# 1  2005        4             4     Fernando Alonso               3.944444
# 2  2006        4             4     Fernando Alonso               4.333333
# 3  2007        8             6      Kimi Räikkönen               3.588235
# 4  2008        1             1      Lewis Hamilton               3.055556
#
#    avg_finish_position
# 0             2.117647
# 1             2.411765
# 2             1.937500
# 3             2.600000
# 4             4.411765

# %%
# champion_avg_position.to_csv('./data/champion_avg_position.csv')

# %% [markdown]
# circuit ranking by charactersics/status - which data characterstics will indicate whether or not the circuit is more difficult or not (accidents, variation in speed, driver winner consistency)

# %% [markdown]
# potentially cluster circuits together

# %%
status_with_drivers = (drivers_status
        >> mutate(status = X.status.map(statusrecode))
        >> mutate(new_statusId = if_else(X.status == 'driver/circuit', 1,0))
        # >> filter_by(X.new_statusId == 1)
)

status_with_drivers.head(5)
# Out:
#    driverId code  fname     lname nationality  raceId  running_season_total  \
# 0         1  HAM  Lewis  Hamilton     British    18.0                  10.0
# 1         1  HAM  Lewis  Hamilton     British    19.0                  14.0
# 2         1  HAM  Lewis  Hamilton     British    20.0                  14.0
# 3         1  HAM  Lewis  Hamilton     British    21.0                  20.0
# 4         1  HAM  Lewis  Hamilton     British    22.0                  28.0
#
#   season_position  wins  year  ...  race_position  race_points laps  \
# 0               1   1.0  2008  ...              1         10.0   58
# 1               1   1.0  2008  ...              5          4.0   56
# 2               3   1.0  2008  ...             13          0.0   56
# 3               2   1.0  2008  ...              3          6.0   66
# 4               3   1.0  2008  ...              2          8.0   58
#
#      race_time  fastestLap fastestLapTime  fastestLapSpeed  statusId  \
# 0  1:34:50.616        39.0       1:27.452          218.300         1
# 1      +46.548        53.0       1:35.462          209.033         1
# 2          NaN        25.0       1:35.520          203.969        11
# 3       +4.187        20.0       1:22.017          204.323         1
# 4       +3.779        31.0       1:26.529          222.085         1
#
#                  status  new_statusId
# 0              finished             0
# 1              finished             0
# 2  extra laps 5 or less             0
# 3              finished             0
# 4              finished             0
#
# [5 rows x 25 columns]

# %%
status_with_drivers.shape
# Out:
# (25191, 25)

# %%
circjoin = status_with_drivers >> inner_join(circuits, by='circuitId')
circ_cleaning = (circjoin
            >> drop(X.url, X.lat, X.lng, X['name'])
            >> mutate(driverId = X.driverId.astype(str))
            >> mutate(raceId = X.raceId.astype(str))
            >> mutate(raceId = X.raceId.map(remove_decimal))
            >> mutate(circuitId = X.circuitId.astype(str))
            >> mutate(circuitId = X.circuitId.map(remove_decimal))
)
# circ_cleaning.head(5)
circuit_laptimes = circ_cleaning >> inner_join(driver_laptimes, by = ['driverId', 'raceId'])
circuit_laptimes_cleaning = (circuit_laptimes
                        >> select(X.circuitRef, X.circuitId, X.driverId, X.code, X.raceId, X.alt, X.laps_x, X.year_y, X.fastestLapTime_y,
                                  X.fastestLap_y, X.fastestLapSpeed_y, X.avg_laptime, X.lap_deviation, X.status_y, X.new_statusId_y)
)


circuit_laptimes_columns = (circuit_laptimes_cleaning.rename(columns={"circuitRef":"circuitRef", "driverId":"driverId", "code":"driverCode", "raceId":"raceId",
                                                                   "time_of_race":"time_of_race", "alt":"altitude", "laps_x":"laps", "laps_y":"laps_y",
                                                                   "fastestLapTime_y":"fastestLapTime", "fastestLapSpeed_y":"fastestLapSpeed", "avg_laptime":"avg_laptime",
                                                                   "lap_deviation":"lap_deviation", "status_y":"status", "new_statusId_y":"new_statusId", 
                                                                   "fastestLap_y":"fastestLap", "year_y":"year"}))

circuit_laptimes_columns.head(5)

# circuits_filter = (circuit_laptimes_columns
#                 >> filter_by(X.new_statusId == 1)
# )
# circuits_filter
# Out:
#     circuitRef circuitId driverId driverCode raceId  altitude  laps  year  \
# 0  albert_park         1        1        HAM     18      10.0    58  2008
# 1  albert_park         1        1        HAM    969      10.0    57  2017
# 2  albert_park         1        1        HAM     36      10.0    58  2007
# 3  albert_park         1        1        HAM    338      10.0    58  2010
# 4  albert_park         1        1        HAM    841      10.0    58  2011
#
#    fastestLapTime  fastestLap  fastestLapSpeed  avg_laptime  lap_deviation  \
# 0          87.452        39.0          218.300    98.114069      20.990357
# 1          87.033        44.0          219.351    88.800825       2.724904
# 2          86.351        20.0          221.083    88.747672       4.088674
# 3          88.506        47.0          215.700    97.352224      16.424708
# 4          90.314        41.0          211.382    92.975103       4.264972
#
#      status  new_statusId
# 0  finished             0
# 1  finished             0
# 2  finished             0
# 3  finished             0
# 4  finished             0

# %%
circuit_laptimes_columns.shape
# Out:
# (7155, 15)

# %%
circuit_laptimes_columns.year.unique()
# Out:
# array(['2008', '2017', '2007', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2018', '2019', '2022', '2006', '2009', '2005',
#        '2004', '2020', '2021'], dtype=object)

# %%
circuits_time_join = alltimes_qualifying >> inner_join(circuits, by = ['circuitId'])
circuits_time_clean = (circuits_time_join
                    >> drop(X.lat, X.lng, X['name'], X.race_round, X.lap_deviation, X.pit_dev, X.url, X.q1, X.q2, X.q3)
                    >> select(X.circuitRef, X.alt, X.raceId, X.driverId, X.year, X.laps, X.fastestLapTime, X.fastestLap, X.fastestLapSpeed, X.avg_laptime)

)
circuits_time_clean.head(5)
# Out:
#     circuitRef    alt raceId driverId  year  laps  fastestLapTime  fastestLap  \
# 0  hungaroring  264.0     10        1  2009  70.0          82.479        16.0
# 1  hungaroring  264.0   1000        1  2018  70.0          81.107        63.0
# 2  hungaroring  264.0   1021        1  2019  70.0          78.528        60.0
# 3  hungaroring  264.0   1033        1  2020  70.0          76.627        70.0
# 4  hungaroring  264.0   1062        1  2021  70.0          78.715        49.0
#
#    fastestLapSpeed  avg_laptime
# 0          191.219    84.341086
# 1          194.454    83.377529
# 2          200.840    81.482800
# 3          205.823    82.463900
# 4          200.363   106.941929

# %%
circuits_time_clean.shape
# Out:
# (6066, 10)
